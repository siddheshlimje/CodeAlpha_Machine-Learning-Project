# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %%
b_covid = pd.read_csv(r"C:\Users\siddhesh limje\Downloads\archive (16)\Unemployment in India.csv")
b_covid
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
a_covid = pd.read_csv(r"C:\Users\siddhesh limje\Downloads\archive (16)\Unemployment_Rate_upto_11_2020.csv")
a_covid
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
b_covid.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
b_covid = b_covid.dropna(how = 'all')

# %%
b_covid
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
b_covid.duplicated().sum()
# Out:
# np.int64(0)

# %%
a_covid.duplicated().sum()
# Out:
# np.int64(0)

# %%
a_covid.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
a_covid['Date'] = pd.to_datetime(a_covid[' Date'])
# Out:
# C:\Users\siddhesh limje\AppData\Local\Temp\ipykernel_8496\342754880.py:1: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   a_covid['Date'] = pd.to_datetime(a_covid[' Date'])

# %%
df.isnull().sum()
# Out:
# Region                                        0
#  Date                                         0
#  Frequency                                    0
#  Estimated Unemployment Rate (%)              0
#  Estimated Employed                           0
#  Estimated Labour Participation Rate (%)      0
# Area                                        267
# Region.1                                    740
# longitude                                   740
# latitude                                    740
# Date                                        740
# dtype: int64

# %%
print(a_covid.columns)
print(b_covid.columns)
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude', 'Date'],
#       dtype='object')
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
a_covid.columns = a_covid.columns.str.strip()
b_covid.columns = b_covid.columns.str.strip()

# %%
print(a_covid.columns)
print(b_covid.columns)
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude', 'Date'],
#       dtype='object')
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
set(b_covid.columns) - set(a_covid.columns)
set(a_covid.columns) - set(b_covid.columns)
# Out:
# {'Region.1', 'latitude', 'longitude'}

# %%
a_covid.columns[a_covid.columns.duplicated()]
b_covid.columns[b_covid.columns.duplicated()]
# Out:
# Index([], dtype='object')

# %%
print(b_covid.columns.is_unique)
print(a_covid.columns.is_unique)
# Out:
# True
# False

# %%
b_covid = b_covid.loc[:, ~b_covid.columns.duplicated()]
a_covid = a_covid.loc[:, ~a_covid.columns.duplicated()]

# %%
df = pd.concat([b_covid, a_covid], ignore_index=True)

# %%
df
# Out:
#               Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 0     Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1     Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2     Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3     Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4     Andhra Pradesh   30-09-2019   Monthly                             5.17
# ...              ...          ...       ...                              ...
# 1002     West Bengal   30-06-2020         M                             7.29
# 1003     West Bengal   31-07-2020         M                             6.83
# 1004     West Bengal   31-08-2020         M                            14.87
# 1005     West Bengal   30-09-2020         M                             9.35
# 1006     West Bengal   31-10-2020         M                             9.98
#
# ...

# %%
df.isnull().sum()
# Out:
# Region                                       0
# Date                                         0
# Frequency                                    0
# Estimated Unemployment Rate (%)              0
# Estimated Employed                           0
# Estimated Labour Participation Rate (%)      0
# Area                                       267
# Region.1                                   740
# longitude                                  740
# latitude                                   740
# dtype: int64

# %%
df = df.drop(columns=['Region.1', 'longitude', 'latitude'])

# %%
df = df.reset_index(drop=True)
df.isnull().sum()
# Out:
# Region                                       0
# Date                                         0
# Frequency                                    0
# Estimated Unemployment Rate (%)              0
# Estimated Employed                           0
# Estimated Labour Participation Rate (%)      0
# Area                                       267
# dtype: int64

# %%
df['Area']=df['Area'].fillna('unknow')

# %%
df
# Out:
#               Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 0     Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1     Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2     Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3     Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4     Andhra Pradesh   30-09-2019   Monthly                             5.17
# ...              ...          ...       ...                              ...
# 1002     West Bengal   30-06-2020         M                             7.29
# 1003     West Bengal   31-07-2020         M                             6.83
# 1004     West Bengal   31-08-2020         M                            14.87
# 1005     West Bengal   30-09-2020         M                             9.35
# 1006     West Bengal   31-10-2020         M                             9.98
#
# ...

# %%
df['Date'].value_counts()
# Out:
# Date
# 29-02-2020    79
# 31-01-2020    79
# 31-03-2020    79
# 31-05-2020    78
# 30-06-2020    77
# 30-04-2020    77
# 31-10-2019    55
# 30-11-2019    55
# 30-06-2019    54
# 31-05-2019    54
# 31-07-2019    54
# 31-08-2019    53
# 31-12-2019    53
# 30-09-2019    52
# 31-07-2020    27
# 31-08-2020    27
# 30-09-2020    27
# 31-10-2020    27
# Name: count, dtype: int64

# %%
df  = df.rename(columns = {'Frequency' : 'frequency'})

# %%
df
# Out:
#               Region         Date frequency  Estimated Unemployment Rate (%)  \
# 0     Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1     Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2     Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3     Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4     Andhra Pradesh   30-09-2019   Monthly                             5.17
# ...              ...          ...       ...                              ...
# 1002     West Bengal   30-06-2020         M                             7.29
# 1003     West Bengal   31-07-2020         M                             6.83
# 1004     West Bengal   31-08-2020         M                            14.87
# 1005     West Bengal   30-09-2020         M                             9.35
# 1006     West Bengal   31-10-2020         M                             9.98
#
# ...

# %%
df.columns = df.columns.astype(str).str.strip()

# %%
df = df.drop('frequency' , axis = 1)

# %%
df
# Out:
#               Region         Date  Estimated Unemployment Rate (%)  \
# 0     Andhra Pradesh   31-05-2019                             3.65
# 1     Andhra Pradesh   30-06-2019                             3.05
# 2     Andhra Pradesh   31-07-2019                             3.75
# 3     Andhra Pradesh   31-08-2019                             3.32
# 4     Andhra Pradesh   30-09-2019                             5.17
# ...              ...          ...                              ...
# 1002     West Bengal   30-06-2020                             7.29
# 1003     West Bengal   31-07-2020                             6.83
# 1004     West Bengal   31-08-2020                            14.87
# 1005     West Bengal   30-09-2020                             9.35
# 1006     West Bengal   31-10-2020                             9.98
#
#       Estimated Employed  Estimated Labour Participation Rate (%)    Area
# 0             11999139.0                                    43.24   Rural
# ...

# %%
df
# Out:
#               Region         Date  Estimated Unemployment Rate (%)  \
# 0     Andhra Pradesh   31-05-2019                             3.65
# 1     Andhra Pradesh   30-06-2019                             3.05
# 2     Andhra Pradesh   31-07-2019                             3.75
# 3     Andhra Pradesh   31-08-2019                             3.32
# 4     Andhra Pradesh   30-09-2019                             5.17
# ...              ...          ...                              ...
# 1002     West Bengal   30-06-2020                             7.29
# 1003     West Bengal   31-07-2020                             6.83
# 1004     West Bengal   31-08-2020                            14.87
# 1005     West Bengal   30-09-2020                             9.35
# 1006     West Bengal   31-10-2020                             9.98
#
#       Estimated Employed  Estimated Labour Participation Rate (%)    Area
# 0             11999139.0                                    43.24   Rural
# ...

# %%
df.describe()
# Out:
#        Estimated Unemployment Rate (%)  Estimated Employed  \
# count                      1007.000000        1.007000e+03
# mean                         11.906991        8.996209e+06
# std                          10.739549        1.020784e+07
# min                           0.000000        4.942000e+04
# 25%                           4.685000        1.639125e+06
# 50%                           8.890000        5.543380e+06
# 75%                          16.125000        1.287115e+07
# max                          76.740000        5.943376e+07
#
#        Estimated Labour Participation Rate (%)
# count                              1007.000000
# mean                                 42.378620
# std                                   8.048542
# min                                  13.330000
# 25%                                  37.835000
# 50%                                  40.880000
# 75%                                  45.315000
# max                                  72.570000

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\siddhesh limje\AppData\Local\Temp\ipykernel_8496\2394721818.py:1: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Region                                             object
# Date                                       datetime64[ns]
# Estimated Unemployment Rate (%)                   float64
# Estimated Employed                                float64
# Estimated Labour Participation Rate (%)           float64
# Area                                               object
# dtype: object

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# %%
df
# Out:
#               Region       Date  Estimated Unemployment Rate (%)  \
# 0     Andhra Pradesh 2019-05-31                             3.65
# 1     Andhra Pradesh 2019-06-30                             3.05
# 2     Andhra Pradesh 2019-07-31                             3.75
# 3     Andhra Pradesh 2019-08-31                             3.32
# 4     Andhra Pradesh 2019-09-30                             5.17
# ...              ...        ...                              ...
# 1002     West Bengal 2020-06-30                             7.29
# 1003     West Bengal 2020-07-31                             6.83
# 1004     West Bengal 2020-08-31                            14.87
# 1005     West Bengal 2020-09-30                             9.35
# 1006     West Bengal 2020-10-31                             9.98
#
#       Estimated Employed  Estimated Labour Participation Rate (%)    Area  \
# 0             11999139.0                                    43.24   Rural
# ...

# %%
plt.figure(figsize = (10 ,5))
plt.plot(df.groupby('Date')['Estimated Unemployment Rate (%)'].mean() , color = 'r' )
plt.title("unemployement rate overtime" , fontweight = 'bold')
plt.show()

# %%
df_clean = df[df['Area'] != 'unknown'].copy()

# %%
Area_wise = df_clean.groupby('Area')['Estimated Unemployment Rate (%)'].mean()

# %%
Area_wise.plot.pie(autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='Estimated Unemployment Rate (%)'>

# %%
regiondf.groupby('Region')['Estimated Unemployment Rate (%)'].mean().sort_values(ascending = False).head()

# %%
region_wise.plot.bar(figsize = (10,5) , rot =45 , color = ['#056875', '#50C2E5', '#C9495E', '#D46600', '#757575']  )
plt.show()

# %%
seasonal_pattern = df.groupby('Month')['Estimated Unemployment Rate (%)'].mean()

# %%
seasonal_pattern.plot.line(figsize = (10 ,5) , color = 'r')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.title('seasonal pattern' , fontweight = 'bold')
plt.show()

# %% [markdown]
# ## 1.Unemployment peaked in April 2020

# %% [markdown]
# ## 2.Urban areas were more affected than rural

# %% [markdown]
# ## 3.Recovery began after 6 month

# %% [markdown]
# ## 4.Seasonal spikes observed in Month 4

# %% [markdown]
# ## 5.Tripura was the most affected state
